# %%
pip install sidrapy

# %%
import sidrapy
import pandas as pd
import numpy

# %% [markdown]
# ## Tabela 5437 - Rendimento médio mensal real das pessoas

# %%
# tabela 5437 Rendimento médio mensal real das pessoas de 14 anos ou mais de idade ocupadas na semana de referência com rendimento de trabalho, habitualmente e efetivamente recebidos no trabalho principal e em todos os trabalhos, por grupo de idade
# Variável: 5935 - Rendimento médio mensal real das pessoas de 14 anos ou mais de idade ocupadas na semana de referência com rendimento de trabalho, efetivamente recebido em todos os trabalhos (Reais) - casas decimais: padrão = 0, máximo = 0
renda_total = sidrapy.get_table(table_code='5437', territorial_level='6',
                         ibge_territorial_code='all', period='all',
                         variable='5935')

# %%
print(renda_total)
# Out:
#                               NC                 NN  \
# 0     Nível Territorial (Código)  Nível Territorial
# 1                              6          Município
# 2                              6          Município
# 3                              6          Município
# 4                              6          Município
# ...                          ...                ...
# 1184                           6          Município
# 1185                           6          Município
# 1186                           6          Município
# 1187                           6          Município
# 1188                           6          Município
#
#                               MC                 MN      V  \
# 0     Unidade de Medida (Código)  Unidade de Medida  Valor
# 1                             38              Reais   3338
# 2                             38              Reais   3105
# 3                             38              Reais   3204
# ...

# %%
# Substitui as colunas pela primeira observação
renda_total.columns = renda_total.iloc[0]
# fatiando df apenas com informações necessarias
renda = renda_total.iloc[1:, [5,6,4,8]]
renda.head()
# Out:
# 0 Município (Código)         Município Valor          Trimestre
# 1            1100205  Porto Velho - RO  3338  1º trimestre 2012
# 2            1100205  Porto Velho - RO  3105  2º trimestre 2012
# 3            1100205  Porto Velho - RO  3204  3º trimestre 2012
# 4            1100205  Porto Velho - RO  2894  4º trimestre 2012
# 5            1100205  Porto Velho - RO  2993  1º trimestre 2013

# %%
renda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1188 entries, 1 to 1188
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Município (Código)  1188 non-null   object
#  1   Município           1188 non-null   object
#  2   Valor               1188 non-null   object
#  3   Trimestre           1188 non-null   object
# dtypes: object(4)
# memory usage: 37.3+ KB

# %%
# Extrair o ano (últimos 4 caracteres da string "Trimestre")
renda['Ano'] = renda['Trimestre'].str[-4:]

# Certifique-se de que 'Valor' está em formato numérico (float)
# Se estiver com vírgula, substitua por ponto:
renda['Valor'] = renda['Valor'].astype(float)

# Agrupar por Município e Ano, e calcular a média dos valores
renda_media_anual = renda.groupby(['Município (Código)', 'Município', 'Ano'])['Valor'].mean().reset_index()

# Exibir o resultado
print(renda_media_anual.head())
# Out:
#   Município (Código)         Município   Ano    Valor
# 0            1100205  Porto Velho - RO  2012  3135.25
# 1            1100205  Porto Velho - RO  2013  2936.25
# 2            1100205  Porto Velho - RO  2014  3176.00
# 3            1100205  Porto Velho - RO  2015  2960.50
# 4            1100205  Porto Velho - RO  2016  2884.25

# %%
# Agrupar por Município e Ano, e calcular a média dos valores
renda_media_anual = renda.groupby(['Município (Código)', 'Município', 'Ano'])['Valor'].mean().reset_index()

# Exibir o resultado
print(renda_media_anual.head())
# Out:
#   Município (Código)         Município   Ano    Valor
# 0            1100205  Porto Velho - RO  2012  3135.25
# 1            1100205  Porto Velho - RO  2013  2936.25
# 2            1100205  Porto Velho - RO  2014  3176.00
# 3            1100205  Porto Velho - RO  2015  2960.50
# 4            1100205  Porto Velho - RO  2016  2884.25

# %%
# renomeando colunas
renda_media_anual.columns = ['mu_cod','mu', 'ano', 'renda_media']

# %%
print(renda_media_anual.head())
# Out:
#     mu_cod                mu   ano  renda_media
# 0  1100205  Porto Velho - RO  2012      3135.25
# 1  1100205  Porto Velho - RO  2013      2936.25
# 2  1100205  Porto Velho - RO  2014      3176.00
# 3  1100205  Porto Velho - RO  2015      2960.50
# 4  1100205  Porto Velho - RO  2016      2884.25

# %% [markdown]
# ## Tabela 6407 - 	População residente, por sexo e grupos de idade

# %%
#Tabela 6407 - 	População residente, por sexo e grupos de idade

# Variável: 606 - População (Mil pessoas) - casas decimais: padrão = 0, máximo = 0

pop_idade_sexo_0 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"58":"1140"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_idade_sexo_1 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"58":"104868"}, #, "58":"1141", "58": "118282", "58": "114535", "58": "40291", "58": "3350", "58": "2793", "58": "1144", "58": "1145", "58": "3299", "58": "3300", "58": "3301", "58": "3302", "58": "1152", "58": "6798"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_idade_sexo_2 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"58":"1141"}, # , "58": "118282", "58": "114535", "58": "40291", "58": "3350", "58": "2793", "58": "1144", "58": "1145", "58": "3299", "58": "3300", "58": "3301", "58": "3302", "58": "1152", "58": "6798"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_idade_sexo_3 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"58": "118282"}, #, "58": "114535", "58": "40291", "58": "3350", "58": "2793", "58": "1144", "58": "1145", "58": "3299", "58": "3300", "58": "3301", "58": "3302", "58": "1152", "58": "6798"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_idade_sexo_4 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"58": "114535"}, #, "58": "40291", "58": "3350", "58": "2793", "58": "1144", "58": "1145", "58": "3299", "58": "3300", "58": "3301", "58": "3302", "58": "1152", "58": "6798"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_idade_sexo_5 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"58": "40291"}, #, "58": "3350", "58": "2793", "58": "1144", "58": "1145", "58": "3299", "58": "3300", "58": "3301", "58": "3302", "58": "1152", "58": "6798"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_idade_sexo_6 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"58": "3350"}, #, "58": "2793", "58": "1144", "58": "1145", "58": "3299", "58": "3300", "58": "3301", "58": "3302", "58": "1152", "58": "6798"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_idade_sexo_7 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"58": "2793"}, #, "58": "1144", "58": "1145", "58": "3299", "58": "3300", "58": "3301", "58": "3302", "58": "1152", "58": "6798"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_idade_sexo_8 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"58": "1144"}, #, "58": "1145", "58": "3299", "58": "3300", "58": "3301", "58": "3302", "58": "1152", "58": "6798"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_idade_sexo_9 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"58": "1145"}, #, "58": "3299", "58": "3300", "58": "3301", "58": "3302", "58": "1152", "58": "6798"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_idade_sexo_10 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"58": "3299"}, #, "58": "3300", "58": "3301", "58": "3302", "58": "1152", "58": "6798"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_idade_sexo_11 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"58": "3300"}, #, "58": "3301", "58": "3302", "58": "1152", "58": "6798"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_idade_sexo_12 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"58": "3301"}, #1140", "58":"104868", "58":"1141", "58": "118282", "58": "114535", "58": "40291", "58": "3350", "58": "2793", "58": "1144", "58": "1145", "58": "3299", "58": "3300", "58": "3301", "58": "3302", "58": "1152", "58": "6798"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_idade_sexo_13 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"58": "3302"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_idade_sexo_14 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"58": "1152"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_idade_sexo_15 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"58": "6798"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

# %%
pop_idade_sexo = pd.concat([pop_idade_sexo_0, pop_idade_sexo_1, pop_idade_sexo_2, pop_idade_sexo_3, pop_idade_sexo_4, pop_idade_sexo_5, pop_idade_sexo_6, pop_idade_sexo_7, pop_idade_sexo_8, pop_idade_sexo_9, pop_idade_sexo_10, pop_idade_sexo_11, pop_idade_sexo_12, pop_idade_sexo_13, pop_idade_sexo_14, pop_idade_sexo_15])

# %%
#?sidrapy.get_table

# %%
print(pop_idade_sexo)
# Out:
#                              NC                 NN  \
# 0    Nível Territorial (Código)  Nível Territorial
# 1                             6          Município
# 2                             6          Município
# 3                             6          Município
# 4                             6          Município
# ..                          ...                ...
# 320                           6          Município
# 321                           6          Município
# 322                           6          Município
# 323                           6          Município
# 324                           6          Município
#
#                              MC                 MN      V                 D1C  \
# 0    Unidade de Medida (Código)  Unidade de Medida  Valor  Município (Código)
# 1                          1572        Mil pessoas     40             1100205
# 2                          1572        Mil pessoas     36             1100205
# ...

# %%
pop_idade_sexo.head()
# Out:
#                            NC                 NN                          MC  \
# 0  Nível Territorial (Código)  Nível Territorial  Unidade de Medida (Código)
# 1                           6          Município                        1572
# 2                           6          Município                        1572
# 3                           6          Município                        1572
# 4                           6          Município                        1572
#
#                   MN      V                 D1C               D1N  \
# 0  Unidade de Medida  Valor  Município (Código)         Município
# 1        Mil pessoas     40             1100205  Porto Velho - RO
# 2        Mil pessoas     36             1100205  Porto Velho - RO
# 3        Mil pessoas     37             1100205  Porto Velho - RO
# 4        Mil pessoas     42             1100205  Porto Velho - RO
#
#             D2C   D2N                D3C        D3N                      D4C  \
# ...

# %%
# Substitui as colunas pela primeira observação
pop_idade_sexo.columns = pop_idade_sexo.iloc[0]
# fatiando df apenas com informações necessarias
pop_idade = pop_idade_sexo.iloc[1:, [5,6,8,4,12]]
pop_idade.head()
# Out:
# 0 Município (Código)         Município   Ano Valor Grupo de idade
# 1            1100205  Porto Velho - RO  2012    40     0 a 4 anos
# 2            1100205  Porto Velho - RO  2013    36     0 a 4 anos
# 3            1100205  Porto Velho - RO  2014    37     0 a 4 anos
# 4            1100205  Porto Velho - RO  2015    42     0 a 4 anos
# 5            1100205  Porto Velho - RO  2016    44     0 a 4 anos

# %%
# Certifique-se de que 'Valor' está em formato numérico (float)
# Se estiver com vírgula, substitua por ponto:
pop_idade['Valor'] = pd.to_numeric(pop_idade['Valor'],errors='coerce')

# Agrupar por Município e Ano, e calcular a média dos valores
idade = pop_idade.groupby(['Município (Código)', 'Município', 'Ano','Grupo de idade'])['Valor'].sum().reset_index()

# Exibir o resultado
print(idade.head())
# Out:
#   Município (Código)         Município   Ano Grupo de idade  Valor
# 0            1100205  Porto Velho - RO  2012     0 a 4 anos   40.0
# 1            1100205  Porto Velho - RO  2012   10 a 13 anos   32.0
# 2            1100205  Porto Velho - RO  2012   14 a 15 anos   19.0
# 3            1100205  Porto Velho - RO  2012   14 a 17 anos   37.0
# 4            1100205  Porto Velho - RO  2012   16 a 17 anos   19.0

# %%
# renomeando colunas
idade.columns = ['mu_cod','mu', 'ano', 'grupo_idade','pop_gp_idade_mil_pessoas']

# %%
idade['grupo_idade'].unique()
# Out:
# array(['0 a 4 anos', '10 a 13 anos', '14 a 15 anos', '14 a 17 anos',
#        '16 a 17 anos', '18 a 19 anos', '20 a 24 anos', '25 a 29 anos',
#        '30 a 39 anos', '40 a 49 anos', '5 a 13 anos', '5 a 9 anos',
#        '50 a 59 anos', '60 a 64 anos', '60 anos ou mais',
#        '65 anos ou mais', 'Grupo de idade'], dtype=object)

# %%
print(idade.head())
# Out:
#     mu_cod                mu   ano   grupo_idade  pop_gp_idade_mil_pessoas
# 0  1100205  Porto Velho - RO  2012    0 a 4 anos                      40.0
# 1  1100205  Porto Velho - RO  2012  10 a 13 anos                      32.0
# 2  1100205  Porto Velho - RO  2012  14 a 15 anos                      19.0
# 3  1100205  Porto Velho - RO  2012  14 a 17 anos                      37.0
# 4  1100205  Porto Velho - RO  2012  16 a 17 anos                      19.0

# %% [markdown]
# ## Monta a tabela de sexo

# %%
#Tabela 6407 - 	População residente, por sexo e grupos de idade

# Variável: 8413 - Distribuição percentual da população por sexo segundo grupos de idade (%) - casas decimais: padrão = 1, máximo = 1

pop_sexo_0 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"2":"4"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_sexo_1 = sidrapy.get_table(table_code='6407',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"2":"5"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

# %%
pop_sexo
# Out:
# 0   Município (Código)         Município   Ano   Valor      Sexo
# 1              1100205  Porto Velho - RO  2012   224.0    Homens
# 2              1100205  Porto Velho - RO  2013   240.0    Homens
# 3              1100205  Porto Velho - RO  2014   240.0    Homens
# 4              1100205  Porto Velho - RO  2015   244.0    Homens
# 5              1100205  Porto Velho - RO  2016   244.0    Homens
# ..                 ...               ...   ...     ...       ...
# 320            5300108     Brasília - DF  2019  1574.0  Mulheres
# 321            5300108     Brasília - DF  2020  1592.0  Mulheres
# 322            5300108     Brasília - DF  2021  1606.0  Mulheres
# 323            5300108     Brasília - DF  2022  1621.0  Mulheres
# 324            5300108     Brasília - DF  2023  1654.0  Mulheres
#
# [649 rows x 5 columns]

# %%
pop_sex = pd.concat([pop_sexo_0, pop_sexo_1])

# %%
pop_sex.head()
# Out:
#                            NC                 NN                          MC  \
# 0  Nível Territorial (Código)  Nível Territorial  Unidade de Medida (Código)
# 1                           6          Município                        1572
# 2                           6          Município                        1572
# 3                           6          Município                        1572
# 4                           6          Município                        1572
#
#                   MN      V                 D1C               D1N  \
# 0  Unidade de Medida  Valor  Município (Código)         Município
# 1        Mil pessoas    224             1100205  Porto Velho - RO
# 2        Mil pessoas    240             1100205  Porto Velho - RO
# 3        Mil pessoas    240             1100205  Porto Velho - RO
# 4        Mil pessoas    244             1100205  Porto Velho - RO
#
#             D2C   D2N                D3C        D3N            D4C     D4N  \
# ...

# %%
# tabela de sexo
# Substitui as colunas pela primeira observação
pop_sex.columns = pop_sex.iloc[0]
# fatiando df apenas com informações necessarias
pop_sexo= pop_sex.iloc[1:, [5,6,8,4,12]]
pop_sexo.head()
# Out:
# 0 Município (Código)         Município   Ano Valor    Sexo
# 1            1100205  Porto Velho - RO  2012   224  Homens
# 2            1100205  Porto Velho - RO  2013   240  Homens
# 3            1100205  Porto Velho - RO  2014   240  Homens
# 4            1100205  Porto Velho - RO  2015   244  Homens
# 5            1100205  Porto Velho - RO  2016   244  Homens

# %%
# Certifique-se de que 'Valor' está em formato numérico (float)
# Se estiver com vírgula, substitua por ponto:
pop_sexo['Valor'] = pd.to_numeric(pop_sexo['Valor'],errors='coerce')

# Agrupar por Município e Ano, e calcular a média dos valores
sexo = pop_sexo.groupby(['Município (Código)', 'Município', 'Ano','Sexo'])['Valor'].sum().reset_index()

# Exibir o resultado
print(sexo.head())
# Out:
#   Município (Código)         Município   Ano      Sexo  Valor
# 0            1100205  Porto Velho - RO  2012    Homens  224.0
# 1            1100205  Porto Velho - RO  2012  Mulheres  234.0
# 2            1100205  Porto Velho - RO  2013    Homens  240.0
# 3            1100205  Porto Velho - RO  2013  Mulheres  228.0
# 4            1100205  Porto Velho - RO  2014    Homens  240.0

# %%
# renomeando colunas
sexo.columns = ['mu_cod','mu', 'ano', 'sexo','pop_sexo_mil_pessoas']

# %%
# Exibir o resultado
print(sexo.head())
# Out:
#     mu_cod                mu   ano      sexo  pop_sexo_mil_pessoas
# 0  1100205  Porto Velho - RO  2012    Homens                 224.0
# 1  1100205  Porto Velho - RO  2012  Mulheres                 234.0
# 2  1100205  Porto Velho - RO  2013    Homens                 240.0
# 3  1100205  Porto Velho - RO  2013  Mulheres                 228.0
# 4  1100205  Porto Velho - RO  2014    Homens                 240.0

# %% [markdown]
# ## Tabela 6408 - População residente, por sexo e cor ou raça

# %%
# Tabela 6408 - População residente, por sexo e cor ou raça

# Variável: 606 - População (Mil pessoas) - casas decimais: padrão = 0, máximo = 0

pop_sexo_raca_0 = sidrapy.get_table(table_code='6408',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"86":"2776"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_sexo_raca_1 = sidrapy.get_table(table_code='6408',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"86":"2777"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

pop_sexo_raca_2 = sidrapy.get_table(table_code='6408',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"86":"2779"},
                              period='all',
                              variable='606',
                              hearder = 'n',
                              format='pandas')

# %%
pop_sexo_raca = pd.concat([pop_sexo_raca_0, pop_sexo_raca_1, pop_sexo_raca_2])

# %%
print(pop_sexo_raca)
# Out:
#                              NC                 NN  \
# 0    Nível Territorial (Código)  Nível Territorial
# 1                             6          Município
# 2                             6          Município
# 3                             6          Município
# 4                             6          Município
# ..                          ...                ...
# 320                           6          Município
# 321                           6          Município
# 322                           6          Município
# 323                           6          Município
# 324                           6          Município
#
#                              MC                 MN      V                 D1C  \
# 0    Unidade de Medida (Código)  Unidade de Medida  Valor  Município (Código)
# 1                          1572        Mil pessoas    126             1100205
# 2                          1572        Mil pessoas    121             1100205
# ...

# %%
# Substitui as colunas pela primeira observação
pop_sexo_raca.columns = pop_sexo_raca.iloc[0]
# fatiando df apenas com informações necessarias
pop_raca = pop_sexo_raca.iloc[1:, [5,6,4,8,12]]
pop_raca.head()
# Out:
# 0 Município (Código)         Município Valor   Ano Cor ou raça
# 1            1100205  Porto Velho - RO   126  2012      Branca
# 2            1100205  Porto Velho - RO   121  2013      Branca
# 3            1100205  Porto Velho - RO   102  2014      Branca
# 4            1100205  Porto Velho - RO   108  2015      Branca
# 5            1100205  Porto Velho - RO   107  2016      Branca

# %%
# Certifique-se de que 'Valor' está em formato numérico (float)
# Se estiver com vírgula, substitua por ponto:
pop_raca['Valor'] = pd.to_numeric(pop_raca['Valor'],errors='coerce')

# Agrupar por Município e Ano, e calcular a média dos valores
raca = pop_raca.groupby(['Município (Código)', 'Município', 'Ano','Cor ou raça'])['Valor'].sum().reset_index()

# Exibir o resultado
print(raca.head())
# Out:
#   Município (Código)         Município   Ano Cor ou raça  Valor
# 0            1100205  Porto Velho - RO  2012      Branca  126.0
# 1            1100205  Porto Velho - RO  2012       Parda  298.0
# 2            1100205  Porto Velho - RO  2012       Preta   31.0
# 3            1100205  Porto Velho - RO  2013      Branca  121.0
# 4            1100205  Porto Velho - RO  2013       Parda  315.0

# %%
# renomeando colunas
raca.columns = ['mu_cod','mu', 'ano', 'raca','pop_raca_mil_pessoas']

# %%
# Exibir o resultado
print(raca.head())
# Out:
#     mu_cod                mu   ano    raca  pop_raca_mil_pessoas
# 0  1100205  Porto Velho - RO  2012  Branca                 126.0
# 1  1100205  Porto Velho - RO  2012   Parda                 298.0
# 2  1100205  Porto Velho - RO  2012   Preta                  31.0
# 3  1100205  Porto Velho - RO  2013  Branca                 121.0
# 4  1100205  Porto Velho - RO  2013   Parda                 315.0

# %% [markdown]
# ## Tabela 7131 - 	Pessoas de 14 anos ou mais de idade, por sexo e grupos de anos de estudo

# %%
# Tabela 7131 - 	Pessoas de 14 anos ou mais de idade, por sexo e grupos de anos de estudo

# 1641  Pessoas de 14 anos ou mais de idade (Mil pessoas) - casas decimais: padrão = 0, máximo = 0

educacao_total_0 = sidrapy.get_table(table_code='7131',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"71":"47808"},
                              period='all',
                              variable='1641',
                              hearder = 'n',
                              format='pandas')

educacao_total_1 = sidrapy.get_table(table_code='7131',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"71":"47809"},
                              period='all',
                              variable='1641',
                              hearder = 'n',
                              format='pandas')

educacao_total_2 = sidrapy.get_table(table_code='7131',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"71":"6663"},
                              period='all',
                              variable='1641',
                              hearder = 'n',
                              format='pandas')

educacao_total_3 = sidrapy.get_table(table_code='7131',
                              territorial_level='6',
                              ibge_territorial_code='all',
                              classifications={"71":"6664"},
                              period='all',
                              variable='1641',
                              hearder = 'n',
                              format='pandas')

# %%
educacao_total = pd.concat([educacao_total_0, educacao_total_1, educacao_total_2, educacao_total_3])

# %%
print(educacao_total)
# Out:
#                              NC                 NN  \
# 0    Nível Territorial (Código)  Nível Territorial
# 1                             6          Município
# 2                             6          Município
# 3                             6          Município
# 4                             6          Município
# ..                          ...                ...
# 158                           6          Município
# 159                           6          Município
# 160                           6          Município
# 161                           6          Município
# 162                           6          Município
#
#                              MC                 MN      V                 D1C  \
# 0    Unidade de Medida (Código)  Unidade de Medida  Valor  Município (Código)
# 1                          1572        Mil pessoas     62             1100205
# 2                          1572        Mil pessoas     39             1100205
# ...

# %%
# Substitui as colunas pela primeira observação
educacao_total.columns = educacao_total.iloc[0]
# fatiando df apenas com informações necessarias
educacao = educacao_total.iloc[1:, [5,6,4,8,12]]
educacao.head()
# Out:
# 0 Município (Código)         Município Valor   Ano  \
# 1            1100205  Porto Velho - RO    62  2016
# 2            1100205  Porto Velho - RO    39  2017
# 3            1100205  Porto Velho - RO    34  2018
# 4            1100205  Porto Velho - RO    37  2019
# 5            1100205  Porto Velho - RO    48  2022
#
# 0          Grupos de anos de estudo
# 1  Sem instrução ou menos de 5 anos
# 2  Sem instrução ou menos de 5 anos
# 3  Sem instrução ou menos de 5 anos
# 4  Sem instrução ou menos de 5 anos
# 5  Sem instrução ou menos de 5 anos

# %%
# Certifique-se de que 'Valor' está em formato numérico (float)
# Se estiver com vírgula, substitua por ponto:
educacao['Valor'] = pd.to_numeric(educacao['Valor'], errors='coerce')

# Agrupar por Município e Ano, e calcular a média dos valores
estudos = educacao.groupby(['Município (Código)', 'Município', 'Ano','Grupos de anos de estudo'])['Valor'].sum().reset_index()

# Exibir o resultado
print(estudos.head())
# Out:
#   Município (Código)         Município   Ano  \
# 0            1100205  Porto Velho - RO  2016
# 1            1100205  Porto Velho - RO  2016
# 2            1100205  Porto Velho - RO  2016
# 3            1100205  Porto Velho - RO  2016
# 4            1100205  Porto Velho - RO  2017
#
#            Grupos de anos de estudo  Valor
# 0                   12 anos ou mais  188.0
# 1                        5 a 8 anos   63.0
# 2                       9 a 11 anos   67.0
# 3  Sem instrução ou menos de 5 anos   62.0
# 4                   12 anos ou mais  195.0

# %%
# renomeando colunas
estudos.columns = ['mu_cod','mu', 'ano','anos_estudo', 'estudos_mil_pessoas']

# %% [markdown]
# ### Pix

# %%
import requests
import io

# %%
# Define a url da API:
url = "https://olinda.bcb.gov.br/olinda/servico/Pix_DadosAbertos/versao/v1/odata/TransacoesPixPorMunicipio(DataBase=@DataBase)?@DataBase='202011'&$format=json&$select=AnoMes,Municipio_Ibge,Municipio,QT_PagadorPF,VL_RecebedorPF,QT_RecebedorPF,QT_PES_PagadorPF,QT_PES_RecebedorPF"

# %%
resposta = requests.get(url)

# %%
print(resposta)
# Out:
# <Response [200]>

# %%
import pprint

# %%
#pprint.pprint(resposta.json())

# %%
dados = resposta.json()['value']

# %%
df = pd.DataFrame(dados)
print(df.head())
# Out:
#    AnoMes  Municipio_Ibge          Municipio  QT_PagadorPF  VL_RecebedorPF  \
# 0  202405       2915502.0           ITAJUÍPE        378480    4.661815e+07
# 1  202212       2903904.0  BOM JESUS DA LAPA        524094    1.171437e+08
# 2  202203       3128600.0         GUARDA-MOR         24861    2.432417e+07
# 3  202212       2915502.0           ITAJUÍPE        197114    3.329263e+07
# 4  202412       2915502.0           ITAJUÍPE        485299    6.255561e+07
#
#    QT_RecebedorPF  QT_PES_PagadorPF  QT_PES_RecebedorPF
# 0          240377             11419               11548
# 1          428389             25167               26792
# 2           18054              2077                2078
# 3          153749              9142                9505
# 4          310297             12046               12178

# %%
# Explora os dados
print(df.columns) # Imprime os nomes das colunas
# Out:
# Index(['AnoMes', 'Municipio_Ibge', 'Municipio', 'QT_PagadorPF',
#        'VL_RecebedorPF', 'QT_RecebedorPF', 'QT_PES_PagadorPF',
#        'QT_PES_RecebedorPF'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300726 entries, 0 to 300725
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   AnoMes              300726 non-null  int64
#  1   Municipio_Ibge      300672 non-null  float64
#  2   Municipio           300726 non-null  object
#  3   QT_PagadorPF        300726 non-null  int64
#  4   VL_RecebedorPF      300726 non-null  float64
#  5   QT_RecebedorPF      300726 non-null  int64
#  6   QT_PES_PagadorPF    300726 non-null  int64
#  7   QT_PES_RecebedorPF  300726 non-null  int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 18.4+ MB

# %%
df.describe()
# Out:
#               AnoMes  Municipio_Ibge  QT_PagadorPF  VL_RecebedorPF  \
# count  300726.000000    3.006720e+05  3.007260e+05    3.007260e+05
# mean   202265.648148    3.253896e+06  4.081229e+05    8.992287e+07
# std       133.206572    9.848685e+05  3.296025e+06    8.186357e+08
# min    202011.000000    1.100015e+06  4.000000e+00    2.939700e+03
# 25%    202112.000000    2.512282e+06  1.889400e+04    4.870209e+06
# 50%    202301.500000    3.146354e+06  6.104500e+04    1.311264e+07
# 75%    202403.000000    4.119214e+06  1.886940e+05    3.759664e+07
# max    202504.000000    5.300108e+06  2.976756e+08    8.481391e+10
#
#        QT_RecebedorPF  QT_PES_PagadorPF  QT_PES_RecebedorPF
# count    3.007260e+05      3.007260e+05        3.007260e+05
# mean     2.908019e+05      1.758185e+04        1.751896e+04
# std      2.325920e+06      1.307746e+05        1.294516e+05
# min      1.000000e+01      2.000000e+00        7.000000e+00
# 25%      1.433600e+04      1.532000e+03        1.524000e+03
# ...

# %%
df.head()
# Out:
#    AnoMes  Municipio_Ibge          Municipio  QT_PagadorPF  VL_RecebedorPF  \
# 0  202405       2915502.0           ITAJUÍPE        378480    4.661815e+07
# 1  202212       2903904.0  BOM JESUS DA LAPA        524094    1.171437e+08
# 2  202203       3128600.0         GUARDA-MOR         24861    2.432417e+07
# 3  202212       2915502.0           ITAJUÍPE        197114    3.329263e+07
# 4  202412       2915502.0           ITAJUÍPE        485299    6.255561e+07
#
#    QT_RecebedorPF  QT_PES_PagadorPF  QT_PES_RecebedorPF
# 0          240377             11419               11548
# 1          428389             25167               26792
# 2           18054              2077                2078
# 3          153749              9142                9505
# 4          310297             12046               12178

# %%
# fatiando df apenas com informações necessarias
df = df.iloc[1:, [0,1,2,5]]
df.head()
# Out:
#    AnoMes  Municipio_Ibge          Municipio  QT_RecebedorPF
# 1  202212       2903904.0  BOM JESUS DA LAPA          428389
# 2  202203       3128600.0         GUARDA-MOR           18054
# 3  202212       2915502.0           ITAJUÍPE          153749
# 4  202412       2915502.0           ITAJUÍPE          310297
# 5  202209       2507903.0        JURIPIRANGA           46740

# %%
# Extrair o ano (primeiros 4 caracteres da string "AnoMes")
df['Municipio_Ibge'] = pd.to_numeric(df['Municipio_Ibge'], errors='coerce').astype('Int64')
df['AnoMes'] = df['AnoMes'].astype(str)
df['Ano'] = df['AnoMes'].str[:4]

# Certifique-se de que 'QT_RecebedorPF' está em formato numérico (float)
# Se estiver com vírgula, substitua por ponto:
df['QT_RecebedorPF'] = df['QT_RecebedorPF'].astype(float)

# Agrupar por Município e Ano, e calcular a média dos valores
df_pix = df.groupby(['Municipio', 'Municipio_Ibge', 'Ano'])['QT_RecebedorPF'].sum().reset_index()

# renomeando colunas
df_pix.columns = ['mu','mu_cod', 'ano', 'QT_RecebedorPF']

# Exibir o resultado
print(df_pix.head())
# Out:
#                 mu   mu_cod   ano  QT_RecebedorPF
# 0  ABADIA DE GOIÁS  5200050  2020          7525.0
# 1  ABADIA DE GOIÁS  5200050  2021        428900.0
# 2  ABADIA DE GOIÁS  5200050  2022        979550.0
# 3  ABADIA DE GOIÁS  5200050  2023       1542558.0
# 4  ABADIA DE GOIÁS  5200050  2024       2278900.0

# %% [markdown]
# ## Merge Data Frames

# %%
renda_media_anual = renda_media_anual.drop(columns=['mu'])
df_pix = df_pix.drop(columns=['mu'])
estudos = estudos.drop(columns=['mu'])
raca = raca.drop(columns=['mu'])
sexo = sexo.drop(columns=['mu'])
idade = idade.drop(columns=['mu'])

# %%
df_estudos_pivotado
# Out:
# anos_estudo   mu_cod   ano  12 anos ou mais  5 a 8 anos  9 a 11 anos  \
# 0            1100205  2016            188.0        63.0         67.0
# 1            1100205  2017            195.0        78.0         75.0
# 2            1100205  2018            213.0        81.0         70.0
# 3            1100205  2019            229.0        79.0         75.0
# 4            1100205  2022            250.0        76.0         67.0
# ..               ...   ...              ...         ...          ...
# 157          5300108  2017           1458.0       380.0        369.0
# 158          5300108  2018           1547.0       375.0        341.0
# 159          5300108  2019           1590.0       364.0        347.0
# 160          5300108  2022           1706.0       333.0        352.0
# 161          5300108  2023           1803.0       328.0        329.0
#
# anos_estudo  Sem instrução ou menos de 5 anos
# 0                                        62.0
# ...

# %%
# Pivotar estudos
df_estudos_pivotado = estudos.pivot_table(
    index=['mu_cod', 'ano'],
    columns='anos_estudo',
    values='estudos_mil_pessoas'
).reset_index()

#df_estudos_pivotado = df_estudos_pivotado.drop(columns=['Grupos de anos de estudo'])
df_estudos_pivotado.head()
# Out:
# anos_estudo   mu_cod   ano  12 anos ou mais  5 a 8 anos  9 a 11 anos  \
# 0            1100205  2016            188.0        63.0         67.0
# 1            1100205  2017            195.0        78.0         75.0
# 2            1100205  2018            213.0        81.0         70.0
# 3            1100205  2019            229.0        79.0         75.0
# 4            1100205  2022            250.0        76.0         67.0
#
# anos_estudo  Sem instrução ou menos de 5 anos
# 0                                        62.0
# 1                                        39.0
# 2                                        34.0
# 3                                        37.0
# 4                                        48.0

# %%
# Pivotar Raça
df_raca_pivotado = raca.pivot_table(
    index=['mu_cod', 'ano'],
    columns='raca',
    values='pop_raca_mil_pessoas'
).reset_index()

#df_estudos_pivotado = df_estudos_pivotado.drop(columns=['Grupos de anos de estudo'])
df_raca_pivotado.head()
# Out:
# raca   mu_cod   ano  Branca  Parda  Preta
# 0     1100205  2012   126.0  298.0   31.0
# 1     1100205  2013   121.0  315.0   29.0
# 2     1100205  2014   102.0  359.0   17.0
# 3     1100205  2015   108.0  357.0   23.0
# 4     1100205  2016   107.0  350.0   35.0

# %%
# Pivotar Idade
df_idade_pivotado = idade.pivot_table(
    index=['mu_cod', 'ano'],
    columns='grupo_idade',
    values='pop_gp_idade_mil_pessoas'
).reset_index()

#df_estudos_pivotado = df_estudos_pivotado.drop(columns=['Grupos de anos de estudo'])
df_idade_pivotado.head()
# Out:
# grupo_idade   mu_cod   ano  0 a 4 anos  10 a 13 anos  14 a 15 anos  \
# 0            1100205  2012        40.0          32.0          19.0
# 1            1100205  2013        36.0          31.0          18.0
# 2            1100205  2014        37.0          32.0          21.0
# 3            1100205  2015        42.0          32.0          19.0
# 4            1100205  2016        44.0          37.0          17.0
#
# grupo_idade  14 a 17 anos  16 a 17 anos  18 a 19 anos  20 a 24 anos  \
# 0                    37.0          19.0          19.0          44.0
# 1                    38.0          21.0          20.0          43.0
# 2                    41.0          19.0          21.0          43.0
# 3                    35.0          15.0          20.0          45.0
# 4                    34.0          17.0          16.0          50.0
#
# grupo_idade  25 a 29 anos  30 a 39 anos  40 a 49 anos  5 a 13 anos  \
# 0                    49.0          69.0          58.0         73.0
# ...

# %%
# Pivotar Idade
df_sexo_pivotado = sexo.pivot_table(
    index=['mu_cod', 'ano'],
    columns='sexo',
    values='pop_sexo_mil_pessoas'
).reset_index()

#df_estudos_pivotado = df_estudos_pivotado.drop(columns=['Grupos de anos de estudo'])
df_sexo_pivotado.head()
# Out:
# sexo   mu_cod   ano  Homens  Mulheres
# 0     1100205  2012   224.0     234.0
# 1     1100205  2013   240.0     228.0
# 2     1100205  2014   240.0     239.0
# 3     1100205  2015   244.0     244.0
# 4     1100205  2016   244.0     255.0

# %%
df_pix
# Out:
#         mu_cod   ano  QT_RecebedorPF
# 0      5200050  2020          7525.0
# 1      5200050  2021        428900.0
# 2      5200050  2022        979550.0
# 3      5200050  2023       1542558.0
# 4      5200050  2024       2278900.0
# ...        ...   ...             ...
# 33403  3533809  2021         26495.0
# 33404  3533809  2022         76319.0
# 33405  3533809  2023        127538.0
# 33406  3533809  2024        195954.0
# 33407  3533809  2025         57308.0
#
# [33408 rows x 3 columns]

# %%
# Merge Data Frames

# Convert mu_cod to Int64
renda_media_anual['mu_cod'] = pd.to_numeric(renda_media_anual['mu_cod'], errors='coerce').astype('Int64')
df_pix['mu_cod'] = pd.to_numeric(df_pix['mu_cod'], errors='coerce').astype('Int64')
df_estudos_pivotado['mu_cod'] = pd.to_numeric(df_estudos_pivotado['mu_cod'], errors='coerce').astype('Int64')
df_raca_pivotado['mu_cod'] = pd.to_numeric(df_raca_pivotado['mu_cod'], errors='coerce').astype('Int64')
df_sexo_pivotado['mu_cod'] = pd.to_numeric(df_sexo_pivotado['mu_cod'], errors='coerce').astype('Int64')
df_idade_pivotado['mu_cod'] = pd.to_numeric(df_idade_pivotado['mu_cod'], errors='coerce').astype('Int64')

# Merge dos dados principais com os dados do Pix
df_final = renda_media_anual.merge(df_pix, on=['mu_cod', 'ano'], how='inner') # restrito aos municípios com renda média

# Merge com dados de escolaridade
df_final = df_final.merge(df_estudos_pivotado, on=['mu_cod', 'ano'], how='outer')

# Merge com raça
df_final = df_final.merge(df_raca_pivotado, on=['mu_cod', 'ano'], how='outer')

# Merge com sexo
df_final = df_final.merge(df_sexo_pivotado, on=['mu_cod', 'ano'], how='outer')

# Merge com idade
df_final = df_final.merge(df_idade_pivotado, on=['mu_cod', 'ano'], how='outer')

# %%
import numpy as np

# %%
# Logaritmizar as variáveis
#df_final['log_QT_RecebedorPF'] = np.log1p(df_final['QT_RecebedorPF'])
#df_final['log_renda_media'] = np.log1p(df_final['renda_media'])
#df_final['log_14 a 17 anos'] = np.log1p(df_final['14 a 17 anos'])
#df_final['log_18 a 19 anos'] = np.log1p(df_final['18 a 19 anos'])
#df_final['log_20 a 24 anos'] = np.log1p(df_final['20 a 24 anos'])
#df_final['log_25 a 29 anos'] = np.log1p(df_final['25 a 29 anos'])
#df_final['log_30 a 39 anos'] = np.log1p(df_final['30 a 39 anos'])
#df_final['log_40 a 49 anos'] = np.log1p(df_final['40 a 49 anos'])
#df_final['log_50 a 59 anos'] = np.log1p(df_final['50 a 59 anos'])
#df_final['log_60 anos ou mais'] =  np.log1p(df_final['60 anos ou mais'])
#df_final['log_Sem instrução ou menos de 5 anos'] = np.log1p(df_final['Sem instrução ou menos de 5 anos'])
#df_final['log_5 a 8 anos'] = np.log1p(df_final['5 a 8 anos'])
#df_final['log_9 a 11 anos'] = np.log1p(df_final['9 a 11 anos'])
#df_final['log_12 anos ou mais'] = np.log1p(df_final['12 anos ou mais'])
#df_final['log_Branca'] = np.log1p(df_final['Branca'])
#df_final['log_Parda'] = np.log1p(df_final['Parda'])
#df_final['log_Preta'] = np.log1p(df_final['Preta'])
#df_final['log_Homens'] = np.log1p(df_final['Homens'])
#df_final['log_Mulheres'] = np.log1p(df_final['Mulheres'])

# %%
df_final.head()
# Out:
#               renda_media  QT_RecebedorPF  12 anos ou mais  5 a 8 anos  \
# mu_cod  ano
# 1100205 2012          NaN             NaN              NaN         NaN
#         2013          NaN             NaN              NaN         NaN
#         2014          NaN             NaN              NaN         NaN
#         2015          NaN             NaN              NaN         NaN
#         2016          NaN             NaN            188.0        63.0
#
#               9 a 11 anos  Sem instrução ou menos de 5 anos  Branca  Parda  \
# mu_cod  ano
# 1100205 2012          NaN                               NaN   126.0  298.0
#         2013          NaN                               NaN   121.0  315.0
#         2014          NaN                               NaN   102.0  359.0
#         2015          NaN                               NaN   108.0  357.0
#         2016         67.0                              62.0   107.0  350.0
#
#               Preta  Homens  ...  log_60 anos ou mais  \
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 351 entries, (np.int64(1100205), np.int64(2012)) to (np.int64(5300108), np.int64(2024))
# Data columns (total 46 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   renda_media                           108 non-null    float64
#  1   QT_RecebedorPF                        108 non-null    float64
#  2   12 anos ou mais                       162 non-null    float64
#  3   5 a 8 anos                            162 non-null    float64
#  4   9 a 11 anos                           162 non-null    float64
#  5   Sem instrução ou menos de 5 anos      162 non-null    float64
#  6   Branca                                324 non-null    float64
#  7   Parda                                 324 non-null    float64
#  8   Preta                                 324 non-null    float64
# ...

# %% [markdown]
# # Modelo

# %%
# !pip install linearmodels

import pandas as pd
import statsmodels.api as sm
from linearmodels.panel import PanelOLS
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.7/115.7 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 3.6 MB/s eta 0:00:00
# ...

# %%
df_final
# Out:
#               renda_media  QT_RecebedorPF  12 anos ou mais  5 a 8 anos  \
# mu_cod  ano
# 1100205 2012          NaN             NaN              NaN         NaN
#         2013          NaN             NaN              NaN         NaN
#         2014          NaN             NaN              NaN         NaN
#         2015          NaN             NaN              NaN         NaN
#         2016          NaN             NaN            188.0        63.0
# ...                   ...             ...              ...         ...
# 5300108 2020      5541.00       4371014.0              NaN         NaN
#         2021          NaN             NaN              NaN         NaN
#         2022      5350.00     302956327.0           1706.0       333.0
#         2023      5504.75     421408774.0           1803.0       328.0
#         2024      5646.00     548179301.0              NaN         NaN
#
#               9 a 11 anos  Sem instrução ou menos de 5 anos  Branca   Parda  \
# mu_cod  ano
# ...

# %%
# Índice multi-nível para painel
df_final = df_final.set_index(['mu_cod', 'ano'])

# Ordenar (boa prática)
df_final = df_final.sort_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-348-0137241edf20> in <cell line: 0>()
#       1 # Índice multi-nível para painel
# ----> 2 df_final = df_final.set_index(['mu_cod', 'ano'])
#       3
#       4 # Ordenar (boa prática)
#       5 df_final = df_final.sort_index()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['mu_cod', 'ano'] are in the columns"

# %%
# Explora os dados
print(df_final.columns) # Imprime os nomes das colunas
# Out:
# Index(['renda_media', 'QT_RecebedorPF', '12 anos ou mais', '5 a 8 anos',
#        '9 a 11 anos', 'Sem instrução ou menos de 5 anos', 'Branca', 'Parda',
#        'Preta', 'Homens', 'Mulheres', '0 a 4 anos', '10 a 13 anos',
#        '14 a 15 anos', '14 a 17 anos', '16 a 17 anos', '18 a 19 anos',
#        '20 a 24 anos', '25 a 29 anos', '30 a 39 anos', '40 a 49 anos',
#        '5 a 13 anos', '5 a 9 anos', '50 a 59 anos', '60 a 64 anos',
#        '60 anos ou mais', '65 anos ou mais', 'log_QT_RecebedorPF',
#        'log_renda_media', 'log_14 a 17 anos', 'log_18 a 19 anos',
#        'log_20 a 24 anos', 'log_25 a 29 anos', 'log_30 a 39 anos',
#        'log_40 a 49 anos', 'log_50 a 59 anos', 'log_60 anos ou mais',
#        'log_Sem instrução ou menos de 5 anos', 'log_5 a 8 anos',
#        'log_9 a 11 anos', 'log_12 anos ou mais', 'log_Branca', 'log_Parda',
#        'log_Preta', 'log_Homens', 'log_Mulheres'],
#       dtype='object')

# %%
# Convert 'ano' to numeric in df_final
df_final = df_final.reset_index()
df_final['ano'] = pd.to_numeric(df_final['ano'])
df_final = df_final.set_index(['mu_cod', 'ano'])
df_final = df_final.sort_index()

# %%
# Definir a variável dependente e independentes
y = df_final['renda_media']
X = df_final[['QT_RecebedorPF',
              '14 a 17 anos', '18 a 19 anos', '20 a 24 anos', '25 a 29 anos', '30 a 39 anos', '40 a 49 anos', '50 a 59 anos', '60 anos ou mais',
              'Sem instrução ou menos de 5 anos', '5 a 8 anos','9 a 11 anos', '12 anos ou mais',
              'Branca', 'Parda','Preta',
              'Homens', 'Mulheres']]

# 4. Adicionar constante
X = sm.add_constant(X)

# 5. Rodar modelo com efeitos fixos
from linearmodels.panel import PanelOLS
model = PanelOLS(y, X, entity_effects=True, check_rank = False).fit(cov_type='robust')
print(model.summary)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:            renda_media   R-squared:                        0.9138
# Estimator:                   PanelOLS   R-squared (Between):             -671.74
# No. Observations:                  54   R-squared (Within):               0.9138
# Date:                Thu, Apr 10 2025   R-squared (Overall):             -656.23
# Time:                        05:40:08   Log-likelihood                   -281.64
# Cov. Estimator:                Robust
#                                         F-statistic:                      5.3028
# Entities:                          27   P-value                           0.0073
# Avg Obs:                       2.0000   Distribution:                    F(18,9)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             100.11
#                                         P-value                           0.0000
# ...
